# %%
#Importing the necessary libraries for data exploration
import pandas
import numpy as np
#Libraries for data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data_file = ('data/bank-additional/bank-additional-full.csv')

# %%
from app.util import *

bank_additional_full = read_csv_file(data_file,sep=";")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d320530fee10> in <module>
#       1 from app.util import *
#       2
# ----> 3 bank_additional_full = read_csv_file(data_file,sep=";")
#
# ~\Desktop\Week 6\app\util.py in read_csv_file(file, sep)
#       1 pd = (pandas)
# ----> 2 def read_csv_file(file):
#       3         csv_file = pd.read_csv(file,sep)
#       4         return csv_file
#
# NameError: name 'pd' is not defined

# %%
def read_csv_file(file,sep):
	csv_file = pd.read_csv(file,sep)
	return csv_file

# %%
bank_additional_full = read_csv_file(data_file, ";")

# %%
bank_additional_full.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
bank_additional_full.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
bank_additional_full.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
bank_additional_full.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
bank_additional_full['y'].value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %% [markdown]
# ### Finding null values:

# %%
bank_additional_full.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# ## Exploration of the data

# %%
shape_bank_additional_full = bank_additional_full.shape
print(f"The data has '(Row, Columns)': {shape_bank_additional_full}")
# Out:
# The data has '(Row, Columns)': (41188, 21)

# %% [markdown]
# ### check the counts for the number of clients' subscription to a term deposit?

# %%
bank_additional_full.groupby('y').count()
# Out:
#        age    job  marital  education  default  housing   loan  contact  \
# y
# no   36548  36548    36548      36548    36548    36548  36548    36548
# yes   4640   4640     4640       4640     4640     4640   4640     4640
#
#      month  day_of_week  duration  campaign  pdays  previous  poutcome  \
# y
# no   36548        36548     36548     36548  36548     36548     36548
# yes   4640         4640      4640      4640   4640      4640      4640
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# y
# no          36548           36548          36548      36548        36548
# yes          4640            4640           4640       4640         4640

# %% [markdown]
# ### Check the categorical job counts for all fields

# %%
bank_additional_full.groupby('job').count()
# Out:
#                  age  marital  education  default  housing   loan  contact  \
# job
# admin.         10422    10422      10422    10422    10422  10422    10422
# blue-collar     9254     9254       9254     9254     9254   9254     9254
# entrepreneur    1456     1456       1456     1456     1456   1456     1456
# housemaid       1060     1060       1060     1060     1060   1060     1060
# management      2924     2924       2924     2924     2924   2924     2924
# retired         1720     1720       1720     1720     1720   1720     1720
# self-employed   1421     1421       1421     1421     1421   1421     1421
# services        3969     3969       3969     3969     3969   3969     3969
# student          875      875        875      875      875    875      875
# technician      6743     6743       6743     6743     6743   6743     6743
# unemployed      1014     1014       1014     1014     1014   1014     1014
# ...

# %% [markdown]
# ### Check each column for Null Count:

# %%
bank_additional_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# #### This shows there is no Null value in all columns

# %%
bank_additional_full_description= bank_additional_full.describe() # data description
bank_additional_full_description
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
data_correlation= bank_additional_full.corr()
data_correlation
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000866  0.004594 -0.034369  0.024365
# duration       -0.000866  1.000000 -0.071699 -0.047577  0.020640
# campaign        0.004594 -0.071699  1.000000  0.052584 -0.079141
# pdays          -0.034369 -0.047577  0.052584  1.000000 -0.587514
# previous        0.024365  0.020640 -0.079141 -0.587514  1.000000
# emp.var.rate   -0.000371 -0.027968  0.150754  0.271004 -0.420489
# cons.price.idx  0.000857  0.005312  0.127836  0.078889 -0.203130
# cons.conf.idx   0.129372 -0.008173 -0.013733 -0.091342 -0.050936
# euribor3m       0.010767 -0.032897  0.135133  0.296899 -0.454494
# nr.employed    -0.017725 -0.044703  0.144095  0.372605 -0.501333
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.000371        0.000857       0.129372   0.010767
# duration           -0.027968        0.005312      -0.008173  -0.032897
# ...

# %%
for cols in bank_additional_full.columns:
    outside = bank_additional_full.groupby(cols).mean()
    
    print("\n")
    print(f"This is the MEAN for {cols}")
    print("\n")
    print(outside)
# Out:
# This is the MEAN for age
#
#
#        duration  campaign       pdays  previous  emp.var.rate  cons.price.idx  \
# age
# 17   420.000000  2.200000  401.600000  1.800000     -3.000000       92.247000
# 18   321.785714  1.321429  680.142857  0.750000     -2.282143       93.166750
# 19   271.500000  2.285714  809.785714  0.666667     -1.869048       93.224119
# 20   288.492308  2.353846  861.400000  0.630769     -1.607692       93.257077
# 21   264.245098  2.029412  892.117647  0.284314     -1.434314       93.334422
# ..          ...       ...         ...       ...           ...             ...
# 91   530.000000  1.500000  999.000000  1.000000     -3.400000       92.379000
# 92   527.500000  1.500000  252.750000  2.000000     -1.750000       93.951500
# 94   134.000000  1.000000  999.000000  1.000000     -3.400000       92.649000
# 95    85.000000  1.000000  999.000000  0.000000     -1.800000       92.843000
# 98   374.000000  1.500000  500.500000  1.000000     -3.400000       92.431000
# ...

# %% [markdown]
# #### Showing the MEAN values for each columns

# %% [markdown]
# ### EDA to help you understand the data, and get insight about the data generation process

# %% [markdown]
# #### 1. Univariate Analysis on all columns ( You can make use of bar charts, pie charts in understanding the categorical columns. Plots such as histograms can be useful for continuous columns. Be creative and think about better graphs to use to communicate what is in the data)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='y', data=bank_additional_full)
plt.xlabel("Y")
plt.ylabel("Counts")
plt.title("Has the client subscribed to a term deposit? (binary: 'yes','no')")
# Out:
# Text(0.5, 1.0, "Has the client subscribed to a term deposit? (binary: 'yes','no')")

# %% [markdown]
# #### This shows that the number of people who have not subscribed to term deposit ismore than the number of people who have.

# %%
plt.figure(figsize=(18,10))
sns.countplot(x='age', data=bank_additional_full)
plt.xlabel("Ages")
plt.ylabel("Counts")
plt.title("Counts of Ages in the Dataset")
# Out:
# Text(0.5, 1.0, 'Counts of Ages in the Dataset')

# %% [markdown]
# #### This shows that people with age (31) had the most number of counts.

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='marital', data=bank_additional_full)
plt.xlabel("Marital Status")
plt.ylabel("Counts")
plt.title("Marital Status Counts")
# Out:
# Text(0.5, 1.0, 'Marital Status Counts')

# %% [markdown]
# #### This shows that the married people responded than other categories.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,6))

bank_additional_full["education"].value_counts().plot(ax=ax[0], kind='bar')
pd.crosstab(bank_additional_full.education, bank_additional_full.y).plot( ax=ax[1],kind='bar')
plt.xlabel("Education Status")
plt.ylabel("Counts")
plt.title("Education Status Counts")
plt.show()

# %%
       
plt.figure(figsize=(12,8))
sns.countplot(x='education', data=bank_additional_full)
plt.xlabel("Education Status")
plt.ylabel("Counts")
plt.title("Education Status Counts")
# Out:
# Text(0.5, 1.0, 'Education Status Counts')

# %% [markdown]
# #### This shows that people with University Degrees responded more than others.

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='default', data=bank_additional_full)

# %%
       
plt.figure(figsize=(15,8))
sns.countplot(x='job', data=bank_additional_full)
plt.xlabel("Education Status")
plt.ylabel("Counts")
plt.title("Education Status Counts")
# Out:
# Text(0.5, 1.0, 'Education Status Counts')

# %%
pd.crosstab(bank_additional_full.job, bank_additional_full.y).plot( kind='bar')
plt.show()

# %% [markdown]
# ### 2. Bivariate Analysis. Carry out some analysis to see how two columns are related. Given that this is a classification problem, cross-tabulation between most categorical columns and the target would be helpful. For numerical columns use boxplots to understand the data separation.

# %%
plt.figure(figsize=(10,5))
plot = sns.boxplot(x = "education", y = "age", hue = "y", data= bank_additional_full)
plt.xticks( rotation=45, horizontalalignment='right' )
plot.set_title('Box plot of Education and Age')
plt.xlabel("Education")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')
